# %%
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

# %%
df = sqlContext.read.csv('hdfs://master:9000/user/hadoop/score__')

# %%
df.show()
# Out:
# +--------+--------------------+-------------------+--------------------+
# |     _c0|                 _c1|                _c2|                 _c3|
# +--------+--------------------+-------------------+--------------------+
# |11410660| 0.02410282357864156|0.11322724009040452|  0.0380952380952381|
# |11530770|0.030011969969341246| 0.1488473894459436| 0.18095238095238095|
# |11590520|0.047617785879841085| 0.1819076531847171|  0.0761904761904762|
# |11215820| 0.04035788371742984|0.23882771574358075|  0.0380952380952381|
# |11110640| 0.04240348793875847|0.21812604396446728|                 0.0|
# |11140605|  0.1326047466658924|0.16781039119599744|  0.3238095238095238|
# |11305625|0.024262961162553578|0.16372527885495053| 0.01904761904761905|
# |11320690|0.029260092965292805|0.22114296732538957| 0.02857142857142857|
# |11545510|0.029841740443923563| 0.5815829204116867|  0.3238095238095238|
# |11545670|0.031687195898502996| 0.2674059913116173| 0.20952380952380953|
# ...

# %%
df = df[df['_c0'].isNotNull() & df['_c1'].isNotNull() & df['_c2'].isNotNull() & df['_c3'].isNotNull()]
df.show()
# Out:
# +--------+--------------------+-------------------+--------------------+
# |     _c0|                 _c1|                _c2|                 _c3|
# +--------+--------------------+-------------------+--------------------+
# |11410660| 0.02410282357864156|0.11322724009040452|  0.0380952380952381|
# |11530770|0.030011969969341246| 0.1488473894459436| 0.18095238095238095|
# |11590520|0.047617785879841085| 0.1819076531847171|  0.0761904761904762|
# |11215820| 0.04035788371742984|0.23882771574358075|  0.0380952380952381|
# |11110640| 0.04240348793875847|0.21812604396446728|                 0.0|
# |11140605|  0.1326047466658924|0.16781039119599744|  0.3238095238095238|
# |11305625|0.024262961162553578|0.16372527885495053| 0.01904761904761905|
# |11320690|0.029260092965292805|0.22114296732538957| 0.02857142857142857|
# |11545510|0.029841740443923563| 0.5815829204116867|  0.3238095238095238|
# |11545670|0.031687195898502996| 0.2674059913116173| 0.20952380952380953|
# ...

# %%
df.repartition(1).write.csv('hdfs://master:9000/user/hadoop/score_non_null')
